# %%
library(tidyverse)
library(Seurat)

library(nebula)
library(fixest)
library(glmGamPoi)
library(limma)
library(edgeR)
library(SingleCellExperiment)
library(data.table)
# Out:
# ── Attaching core tidyverse packages ──────────────────────────────────────────────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.4     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Attaching SeuratObject
#
#
# Attaching package: ‘glmGamPoi’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     vars
#
#
# The following object is masked from ‘package:ggplot2’:
#
#     vars
#
#
# Loading required package: SummarizedExperiment
#
# Loading required package: MatrixGenerics
#
# Loading required package: matrixStats
#
#
# Attaching package: ‘matrixStats’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     count
#
#
#
# Attaching package: ‘MatrixGenerics’
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
#
# Loading required package: GenomicRanges
#
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following object is masked from ‘package:limma’:
#
#     plotMA
#
#
# The following objects are masked from ‘package:lubridate’:
#
#     intersect, setdiff, union
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     combine, intersect, setdiff, union
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, intersect, is.unsorted, lapply, Map, mapply,
#     match, mget, order, paste, pmax, pmax.int, pmin, pmin.int,
#     Position, rank, rbind, Reduce, rownames, sapply, setdiff, sort,
#     table, tapply, union, unique, unsplit, which.max, which.min
#
#
# Loading required package: S4Vectors
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following objects are masked from ‘package:lubridate’:
#
#     second, second<-
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     first, rename
#
#
# The following object is masked from ‘package:tidyr’:
#
#     expand
#
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Loading required package: IRanges
#
#
# Attaching package: ‘IRanges’
#
#
# The following object is masked from ‘package:lubridate’:
#
#     %within%
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     collapse, desc, slice
#
#
# The following object is masked from ‘package:purrr’:
#
#     reduce
#
#
# Loading required package: GenomeInfoDb
#
# Loading required package: Biobase
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
#
# Attaching package: ‘Biobase’
#
#
# The following object is masked from ‘package:MatrixGenerics’:
#
#     rowMedians
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
#
#
# Attaching package: ‘SummarizedExperiment’
#
#
# The following object is masked from ‘package:SeuratObject’:
#
#     Assays
#
#
# The following object is masked from ‘package:Seurat’:
#
#     Assays
#
#
#
# Attaching package: ‘SingleCellExperiment’
#
#
# The following object is masked from ‘package:edgeR’:
#
#     cpm
#
#
#
# Attaching package: ‘data.table’
#
#
# The following object is masked from ‘package:SummarizedExperiment’:
#
#     shift
#
#
# The following object is masked from ‘package:GenomicRanges’:
#
#     shift
#
#
# The following object is masked from ‘package:IRanges’:
#
#     shift
#
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, second
#
#
# The following objects are masked from ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last
#
#
# The following object is masked from ‘package:purrr’:
#
#     transpose

# %%
selectCol <- function(mat, j.col){    
    x.col.dense <- rep(0,nrow(mat))
    p.begin <- mat@p[j.col]+1
    p.end <- mat@p[j.col+1]
    i.col <- mat@i[p.begin:p.end]+1 # i counts from 0
    x.col <- mat@x[p.begin:p.end]
    x.col.dense[i.col] <- x.col
    return(x.col.dense)
    }

selectCols <- function(mat, j.cols){    
    return(sapply(j.cols, selectCol, mat=mat))
    }

fixest.mult <- function(formula, count, df){
    df.result <- data.frame(matrix(nrow=0, ncol=4))
    colnames(df.result) <- c('Estimate', 'Std. Error', 't value', 'Pr(>|t|)')
    for (j in 1:ncol(count)){
        df$y <- selectCol(count, j)
        fit <- fixest::fepois(formula, vcov='hetero', data=df)
        df.result[colnames(count)[j],] <- coeftable(fit)['tx_cell',] # fixed effect o/x 에 따라 다르게 들어가야함
        } 
    return(df.result)
    }

nebula.mult <- function(formula, count, df){
    pred <- model.matrix(formula, data=df)
    sid <- df$id
    fit.nebula <- nebula::nebula(
        count,
        sid,
        pred=pred,
        cpc=0,
        mincp=0
        )
    fit.result <- fit.nebula$summary
    rownames(fit.result) <- fit.result$gene
    return(
            fit.result %>%
            mutate(
                Estimate=logFC_tx_cell,
                'Std. Error'=se_tx_cell,
                't value'=logFC_tx_cell/se_tx_cell,
                'Pr(>|t|)'=p_tx_cell
                ) %>%
            select(Estimate, 'Std. Error', 't value', 'Pr(>|t|)')
        )
    }

glmgp.mult <- function(formula, count, df){
    sce.obj <- SingleCellExperiment::SingleCellExperiment(list(counts=count), colData=df)
    sce.pb <- glmGamPoi::pseudobulk(
        sce.obj,
        group_by=vars(id, tx_cell),
        verbose=FALSE
        )

    fit <- glmGamPoi::glm_gp(sce.pb, design=~1+tx_cell)
    test <- glmGamPoi::test_de(fit, reduced_design=~1)
    
    beta <- fit$Beta[,'tx_cell']
    pval <- test$pval
    tval <- qnorm(1-pval/2) * sign(beta)
    se <- beta/tval
    result <- cbind(beta, se, tval, pval)
    colnames(result) <- c('Estimate', 'Std. Error', 't value', 'Pr(>|t|)')
    return(result)
    }

glmgp.cell.mult <- function(formula, count, df){
    sce.obj <- SingleCellExperiment::SingleCellExperiment(list(counts=count), colData=df)
    fit <- glmGamPoi::glm_gp(sce.obj, design=~1+tx_cell, on_disk=FALSE, size_factors=FALSE)
    test <- glmGamPoi::test_de(fit, reduced_design=~1)
    
    beta <- fit$Beta[,'tx_cell']
    pval <- test$pval
    tval <- qnorm(1-pval/2) * sign(beta)
    se <- beta/tval
    result <- cbind(beta, se, tval, pval)
    colnames(result) <- c('Estimate', 'Std. Error', 't value', 'Pr(>|t|)')
    return(result)
    }

edger.mult <- function(formula, count, df){
    sce.obj <- SingleCellExperiment::SingleCellExperiment(list(counts=count), colData=df)
    sce.pb <- glmGamPoi::pseudobulk(
        sce.obj,
        group_by=vars(id, tx_cell),
        verbose=FALSE
        )

    design <- model.matrix(~1+tx_cell, data=colData(sce.pb))
    edger.obj <- edgeR::DGEList(counts(sce.pb))
    edger.obj <- edgeR::estimateDisp(edger.obj, design)
    fit <- edgeR::glmQLFit(y=edger.obj, design=design)
    test <- edgeR::glmTreat(fit, coef=2)

    beta <- test$coefficients[,'tx_cell']
    pval <- test$table[,'PValue']
    tval <- qnorm(1-pval/2) * sign(beta)
    se <- beta/tval

    result <- cbind(beta, se, tval, pval)
    colnames(result) <- c('Estimate', 'Std. Error', 't value', 'Pr(>|t|)')
    
    return(result)
    }

limma.mult <- function(formula, count, df){
    sce.obj <- SingleCellExperiment::SingleCellExperiment(list(counts=count), colData=df)
    sce.pb <- glmGamPoi::pseudobulk(
        sce.obj,
        group_by=vars(id, tx_cell),
        verbose=FALSE
        )

    design <- model.matrix(~1+tx_cell, data=colData(sce.pb))
    edger.obj <- edgeR::DGEList(counts(sce.pb))
    v <- limma::voom(edger.obj, design)
    vfit <- limma::lmFit(v, design)
    efit <- limma::eBayes(vfit)
    
    beta <- efit$coefficients[,'tx_cell'] * log(2)
    pval <- efit$p.value[,'tx_cell']
    tval <- qnorm(1-pval/2) * sign(beta)
    se <- beta/tval

    result <- cbind(beta, se, tval, pval)
    colnames(result) <- c('Estimate', 'Std. Error', 't value', 'Pr(>|t|)')
    
    return(result)
    }

# %%
obj <- readRDS("/data02/hanbin973/deg_practical/datasets/kang.2018.sce.rds")

# %%
colData(obj)
# Out:
# DataFrame with 28458 rows and 4 columns
#                  group_id patient_id sample_id      cluster_id
#                  <factor>   <factor>  <factor>        <factor>
# AAACATACAATGCC-1     ctrl       107   ctrl107  CD4 T cells
# AAACATACATTTCC-1     ctrl       1016  ctrl1016 CD14+ Monocytes
# AAACATACCAGAAA-1     ctrl       1256  ctrl1256 CD14+ Monocytes
# AAACATACCAGCTA-1     ctrl       1256  ctrl1256 CD14+ Monocytes
# AAACATACCATGCA-1     ctrl       1488  ctrl1488 CD4 T cells
# ...                   ...        ...       ...             ...
# TTTGCATGCTAAGC-1     stim       107   stim107      CD4 T cells
# TTTGCATGGGACGA-1     stim       1488  stim1488     CD4 T cells
# TTTGCATGGTGAGG-1     stim       1488  stim1488     CD4 T cells
# TTTGCATGGTTTGG-1     stim       1244  stim1244     CD4 T cells
# TTTGCATGTCTTAC-1     stim       1016  stim1016     CD4 T cells

# %%
as.data.frame(colData(obj)) %>% 
    group_by(group_id, patient_id, .drop=FALSE) %>% 
    summarise(n=n()) %>% 
    pivot_wider(names_from=patient_id, values_from=n)
# Out:
# `summarise()` has grouped output by 'group_id'. You can override using the `.groups` argument.
#   group_id 101  107 1015 1016 1039 1244 1256 1488
# 1 ctrl     1022 641 3131 2173 476  2241 2439 2362
# 2 stim     1321 619 2631 1938 689  1717 2217 2841

# %%
# adopted from the authors
target_gene_overexpression <- function(obj){
    
    # extract information
    cell_types <- unique(colData(obj)$cluster_id)
    result.list <- list()
    for (cell_type in cell_types){
        obj.ct <- obj[,colData(obj)$cluster_id == cell_type]
        cnt <- counts(obj.ct)
        col.data <- as.data.frame(colData(obj.ct))[,c('group_id', 'patient_id', 'cluster_id')]
        colnames(col.data) <- c('tx_cell', 'donor_id', 'cell_type')
        col.data$tx_cell <- ifelse(col.data$tx_cell == 'ctrl', 0, 1)

        col.data <- col.data %>% arrange(donor_id)
        col.data$id <- col.data$donor_id
        cnt <- cnt[,rownames(col.data)]
        cnt <- cnt[rowMeans(cnt) > 0.01,]

        func.list <- list(nebula.mult, glmgp.mult, edger.mult, limma.mult, glmgp.cell.mult, fixest.mult)
        #func.list <- list(glmgp.mult)
        data.list <- list(cnt, cnt, cnt, cnt, cnt, t(cnt))
        form.list <- list(
            as.formula('~tx_cell'),
            as.formula('~tx_cell'),
            as.formula('~tx_cell'),
            as.formula('~tx_cell'),
            as.formula('~tx_cell'),
            as.formula('y~tx_cell | id') # 
            )

        result.list.ct <- list()
        for (i in 1:length(func.list)){
            df <- as.data.frame(func.list[[i]](
                form.list[[i]],
                data.list[[i]],
                col.data
                ))
            df$gene <- rownames(df)
            result.list.ct[[i]] <- df
            }
        names(result.list.ct) <- c('NB GLMM', 'glmGamPoi (Pb)', 'edgeR (Pb)', 'limma (Pb)', 'glmGamPoi (cell)', 'robust GLM (cell)')
        #names(result.list.ct) <- c('glmGamPoi (Pb)')
        result.list[[cell_type]] <- rbindlist(result.list.ct, idcol='method')
    }
    
    return(rbindlist(result.list, idcol='celltype'))
}

# %%
x <- target_gene_overexpression(obj)
saveRDS(x, 'kang.result.rds')
# Out:
# Remove  0  genes having low expression.
# Analyzing  5738  genes with  8  subjects and  11848  cells.
# NOTE: 1 fixed-effect (770 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (420 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (3,483 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (520 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (420 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (770 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (420 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (520 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (420 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (420 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (420 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (420 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (420 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (420 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (770 observations) removed because of only 0 outcomes.
# Remove  0  genes having low expression.
# Analyzing  6147  genes with  8  subjects and  6295  cells.
# NOTE: 1 fixed-effect (458 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (458 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (315 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (315 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (1,166 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (458 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (315 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (315 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (315 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (315 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (742 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (458 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (315 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (851 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (315 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (315 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (458 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (742 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (458 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (315 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (315 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (1,162 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (458 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (315 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (315 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (315 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (538 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (315 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (315 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (315 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (458 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (315 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (315 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (315 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (315 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (315 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (1,166 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (458 observations) removed because of only 0 outcomes.
# Remove  0  genes having low expression.
# Analyzing  7439  genes with  8  subjects and  455  cells.
# NOTE: 6 fixed-effects (307 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (63 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (225 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (50 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (86 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (175 observations) removed because of only 0 outcomes.
#
# NOTE: 5 fixed-effects (268 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (148 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (147 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (145 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (111 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (132 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (186 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (36 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (111 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (190 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (147 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (187 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (59 observations) removed because of only 0 outcomes.
#
# NOTE: 5 fixed-effects (246 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (59 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (124 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (86 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (50 observations) removed because of only 0 outcomes.
#
# NOTE: 5 fixed-effects (229 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (145 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (221 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (109 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (63 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (59 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (116 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (257 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (82 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (145 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (102 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (170 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (89 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (189 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (50 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (145 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (36 observations) removed because of only 0 outcomes.
#
# NOTE: 5 fixed-effects (227 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (109 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (168 observations) removed because of only 0 outcomes.
#
# NOTE: 6 fixed-effects (288 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (120 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (86 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (109 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (198 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (272 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (189 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (59 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (141 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (170 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (50 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (225 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (59 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (88 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (175 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (200 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (132 observations) removed because of only 0 outcomes.
#
# NOTE: 5 fixed-effects (236 observations) removed because of only 0 outcomes.
#
# NOTE: 5 fixed-effects (227 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (168 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (50 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (168 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (200 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (164 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (36 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (50 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (50 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (122 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (183 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (168 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (63 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (122 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 5 fixed-effects (333 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (145 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (111 observations) removed because of only 0 outcomes.
#
# NOTE: 5 fixed-effects (285 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (59 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (89 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (116 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (36 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (272 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (105 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (82 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (105 observations) removed because of only 0 outcomes.
#
# NOTE: 7 fixed-effects (354 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (190 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (82 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (95 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (132 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (66 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (152 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (141 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (36 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (132 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (109 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (145 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (59 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (150 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (93 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (109 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (36 observations) removed because of only 0 outcomes.
#
# NOTE: 5 fixed-effects (227 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (36 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (61 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (147 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (118 observations) removed because of only 0 outcomes.
#
# NOTE: 5 fixed-effects (276 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (50 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (116 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (225 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (249 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (145 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (147 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (109 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (59 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 5 fixed-effects (206 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (82 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (206 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (50 observations) removed because of only 0 outcomes.
#
# NOTE: 5 fixed-effects (234 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (61 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (59 observations) removed because of only 0 outcomes.
#
# NOTE: 5 fixed-effects (269 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (141 observations) removed because of only 0 outcomes.
#
# NOTE: 5 fixed-effects (234 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (50 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (120 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (59 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (61 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 5 fixed-effects (245 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (185 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (93 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (156 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (170 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (59 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (36 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (84 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (118 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (152 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (118 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (132 observations) removed because of only 0 outcomes.
#
# NOTE: 5 fixed-effects (301 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (187 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (86 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (249 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (163 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (219 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (204 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (175 observations) removed because of only 0 outcomes.
#
# NOTE: 5 fixed-effects (227 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (50 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 5 fixed-effects (289 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (186 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (150 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (82 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (111 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (125 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (36 observations) removed because of only 0 outcomes.
#
# NOTE: 5 fixed-effects (268 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (189 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (63 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (111 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (36 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (145 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (97 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (219 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (171 observations) removed because of only 0 outcomes.
#
# NOTE: 5 fixed-effects (234 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (226 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (59 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (141 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (183 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (148 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (145 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (141 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (145 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (50 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (50 observations) removed because of only 0 outcomes.
#
# NOTE: 5 fixed-effects (206 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (124 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (111 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (190 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (36 observations) removed because of only 0 outcomes.
#
# NOTE: 6 fixed-effects (272 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (36 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (50 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 5 fixed-effects (259 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (66 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (147 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (122 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (143 observations) removed because of only 0 outcomes.
#
# NOTE: 5 fixed-effects (206 observations) removed because of only 0 outcomes.
#
# NOTE: 5 fixed-effects (276 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (154 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (59 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (88 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (63 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (86 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (147 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (152 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (59 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (36 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (82 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (189 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (82 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (36 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (36 observations) removed because of only 0 outcomes.
#
# NOTE: 5 fixed-effects (211 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (93 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (109 observations) removed because of only 0 outcomes.
#
# NOTE: 5 fixed-effects (206 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (233 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (86 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (36 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (116 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (109 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (59 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (36 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (36 observations) removed because of only 0 outcomes.
#
# NOTE: 5 fixed-effects (269 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (102 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (86 observations) removed because of only 0 outcomes.
#
# NOTE: 5 fixed-effects (234 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (191 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (217 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (116 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (109 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (187 observations) removed because of only 0 outcomes.
#
# NOTE: 5 fixed-effects (346 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (109 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (109 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (124 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (141 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (156 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (242 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (145 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (186 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (36 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (132 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (84 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (59 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (82 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (150 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (59 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 5 fixed-effects (213 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (116 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (111 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (206 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (82 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (116 observations) removed because of only 0 outcomes.
#
# NOTE: 5 fixed-effects (248 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (59 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (122 observations) removed because of only 0 outcomes.
#
# NOTE: 5 fixed-effects (213 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (86 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (145 observations) removed because of only 0 outcomes.
#
# NOTE: 6 fixed-effects (335 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (118 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (50 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (95 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (50 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (63 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (59 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (63 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (168 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (93 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (36 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (148 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (129 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (200 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (82 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (89 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (102 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (124 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (118 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (36 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (86 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (36 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (246 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (93 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (129 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (36 observations) removed because of only 0 outcomes.
#
# NOTE: 5 fixed-effects (229 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (152 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (120 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (61 observations) removed because of only 0 outcomes.
#
# NOTE: 5 fixed-effects (284 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (143 observations) removed because of only 0 outcomes.
#
# NOTE: 5 fixed-effects (234 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (161 observations) removed because of only 0 outcomes.
#
# NOTE: 5 fixed-effects (257 observations) removed because of only 0 outcomes.
#
# NOTE: 5 fixed-effects (253 observations) removed because of only 0 outcomes.
#
# NOTE: 5 fixed-effects (272 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (243 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (89 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (162 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (59 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (147 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (97 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (36 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (50 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (147 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (66 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (93 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (105 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (200 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (93 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (116 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (193 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (122 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (82 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (50 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (116 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (116 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (148 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (50 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (109 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (129 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (36 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (151 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (120 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (118 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (187 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (164 observations) removed because of only 0 outcomes.
#
# NOTE: 5 fixed-effects (287 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (63 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (63 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (66 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (213 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (272 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (120 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (59 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (160 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (97 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (59 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (141 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (308 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (175 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (120 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (221 observations) removed because of only 0 outcomes.
#
# NOTE: 5 fixed-effects (270 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (164 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (196 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (120 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 5 fixed-effects (249 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (36 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (59 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (209 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (86 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (230 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (148 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (168 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (59 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (147 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (36 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (86 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (50 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (59 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 5 fixed-effects (206 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (183 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (61 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (50 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (175 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (184 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (160 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 5 fixed-effects (257 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (82 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (109 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (89 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (238 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (82 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (95 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (120 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (63 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (59 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (124 observations) removed because of only 0 outcomes.
#
# NOTE: 5 fixed-effects (206 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (50 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (210 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (265 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (59 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (124 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (89 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (88 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (36 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (145 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (86 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (206 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (50 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (89 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 5 fixed-effects (272 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (116 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (86 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (143 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (36 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (120 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (59 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (269 observations) removed because of only 0 outcomes.
#
# NOTE: 5 fixed-effects (229 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (63 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 6 fixed-effects (288 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (145 observations) removed because of only 0 outcomes.
#
# NOTE: 5 fixed-effects (206 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (82 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (219 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (120 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (111 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (82 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (177 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (179 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (122 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (109 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (101 observations) removed because of only 0 outcomes.
#
# NOTE: 6 fixed-effects (312 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 5 fixed-effects (249 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 5 fixed-effects (206 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (86 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (86 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (86 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (50 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (109 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (184 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (59 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (88 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (168 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (59 observations) removed because of only 0 outcomes.
#
# NOTE: 5 fixed-effects (211 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (59 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (152 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (50 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (63 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (36 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (210 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (225 observations) removed because of only 0 outcomes.
#
# NOTE: 5 fixed-effects (211 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (105 observations) removed because of only 0 outcomes.
#
# NOTE: 5 fixed-effects (269 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (200 observations) removed because of only 0 outcomes.
#
# ...
#
# NOTE: 3 fixed-effects (170 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (82 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (61 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (27 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (23 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (109 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (238 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (202 observations) removed because of only 0 outcomes.
#
# NOTE: 4 fixed-effects (168 observations) removed because of only 0 outcomes.
# Remove  0  genes having low expression.
# Analyzing  5863  genes with  8  subjects and  2289  cells.
# NOTE: 1 fixed-effect (99 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (302 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (99 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (99 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (99 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (203 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (153 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (153 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (153 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (257 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (388 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (99 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (325 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (302 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (257 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (99 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (99 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (153 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (153 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (99 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (99 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (99 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (99 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (99 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (153 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (203 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (99 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (302 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (99 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (99 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (99 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (99 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (153 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (370 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (99 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (153 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (153 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (153 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (99 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (99 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (257 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (153 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (99 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (325 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (99 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (99 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (99 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (99 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (153 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (573 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (271 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (271 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (424 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (611 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (153 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (99 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (153 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (153 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (99 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (442 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (99 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (271 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 3 fixed-effects (356 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (325 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (99 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (512 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (153 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (271 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (309 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (153 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (153 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (99 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (153 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (203 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (99 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (203 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (99 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (203 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (99 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (153 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (271 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (203 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (302 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (99 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (99 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (153 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (99 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (153 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (153 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (153 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (99 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (99 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (99 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (153 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (271 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (302 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (99 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (99 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (99 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 2 fixed-effects (153 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (203 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (203 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.
#
# NOTE: 1 fixed-effect (54 observations) removed because of only 0 outcomes.

# %%
result <- readRDS('kang.result.rds')

# %%
head(result)
# Out:
#   celltype    method  Estimate    Std. Error t value     Pr(>|t|)     gene
# 1 CD4 T cells NB GLMM  0.05662706 0.06440173   0.8792787 3.792502e-01 NOC2L
# 2 CD4 T cells NB GLMM  1.30265284 0.14964196   8.7051307 3.172091e-18 HES4
# 3 CD4 T cells NB GLMM  3.43307187 0.02901797 118.3084857 0.000000e+00 ISG15
# 4 CD4 T cells NB GLMM -0.06544499 0.10404990  -0.6289770 5.293641e-01 TNFRSF18
# 5 CD4 T cells NB GLMM  0.17667338 0.07957735   2.2201466 2.640882e-02 TNFRSF4
# 6 CD4 T cells NB GLMM -0.18788198 0.07383974  -2.5444563 1.094480e-02 SDF4

# %%
df.hm <- result %>%
    mutate(gene_celltype = paste(gene, celltype, sep='_')) %>%
    select(gene_celltype, method, `Pr(>|t|)`) %>%
    pivot_wider(names_from=method, values_from=`Pr(>|t|)`)
df.hm <- as.data.frame(df.hm[,2:ncol(df.hm)])
df.hm[!is.finite(df.hm[,1]),] <- 1
mat <- as.matrix(df.hm)
pval <- 0.05/6257
mat <- (mat < pval)
cor.mat <- round((t(mat) %*% mat)/nrow(mat) * 100,2)
name.ord <- c('glmGamPoi (Pb)', 'edgeR (Pb)', 'limma (Pb)', 'glmGamPoi (cell)', 'fixest (cell)', 'NB GLMM')
write.csv(cor.mat[name.ord, name.ord], 'kang.pow.csv')
cor.mat[name.ord, name.ord]
# Out:
#                  glmGamPoi (Pb) edgeR (Pb) limma (Pb) glmGamPoi (cell)
# glmGamPoi (Pb)   6.54           5.34       6.25        6.53
# edgeR (Pb)       5.34           5.55       5.32        5.49
# limma (Pb)       6.25           5.32       6.76        6.72
# glmGamPoi (cell) 6.53           5.49       6.72       12.32
# fixest (cell)    6.47           5.42       6.63       11.23
# NB GLMM          6.45           5.38       6.62       11.56
#                  fixest (cell) NB GLMM
# glmGamPoi (Pb)    6.47          6.45
# edgeR (Pb)        5.42          5.38
# limma (Pb)        6.63          6.62
# glmGamPoi (cell) 11.23         11.56
# fixest (cell)    12.55         11.15
# NB GLMM          11.15         11.68

# %%
df.hm <- result %>%
    mutate(gene_celltype = paste(gene, celltype, sep='_')) %>%
    select(gene_celltype, method, `Pr(>|t|)`) %>%
    pivot_wider(names_from=method, values_from=`Pr(>|t|)`)
df.hm <- as.data.frame(df.hm[,2:ncol(df.hm)])
df.hm[!is.finite(df.hm[,1]),] <- 1
mat <- as.matrix(df.hm)
cor.mat <- cor(mat, method = c("spearman"))
name.ord <- c('glmGamPoi (Pb)', 'edgeR (Pb)', 'limma (Pb)', 'glmGamPoi (cell)', 'fixest (cell)', 'NB GLMM')
write.csv(cor.mat[name.ord, name.ord], 'kang.sp.csv')
cor.mat[name.ord, name.ord]
# Out:
#                  glmGamPoi (Pb) edgeR (Pb) limma (Pb) glmGamPoi (cell)
# glmGamPoi (Pb)   1.0000000      0.9729917  0.9496521  0.9033430
# edgeR (Pb)       0.9729917      1.0000000  0.9118087  0.8792684
# limma (Pb)       0.9496521      0.9118087  1.0000000  0.8571769
# glmGamPoi (cell) 0.9033430      0.8792684  0.8571769  1.0000000
# fixest (cell)    0.8848327      0.8672583  0.8319463  0.9781600
# NB GLMM          0.8608584      0.8265981  0.8378374  0.9592919
#                  fixest (cell) NB GLMM
# glmGamPoi (Pb)   0.8848327     0.8608584
# edgeR (Pb)       0.8672583     0.8265981
# limma (Pb)       0.8319463     0.8378374
# glmGamPoi (cell) 0.9781600     0.9592919
# fixest (cell)    1.0000000     0.9159255
# NB GLMM          0.9159255     1.0000000
